# %% [markdown]
# ## Beginning of the document
#
# Can insert a markdown cell or code cell before or after existing markdown or code cell, click on the triple horizontal dots.

# %% [markdown]
# ## making an edit
# Making an edit

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3, 4, 5])
plt.ylabel('Numbers')
plt.show()

# %% [markdown]
# # SECOND SNIPPET

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.plot()
# Out:
# []

# %% [markdown]
# Test `[0,1,2,3]`. Make **bold** or *italics?*.

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro')
plt.axis([0, 6, 0, 20])
plt.show()

# %%
import numpy as np

# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)

# red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()
